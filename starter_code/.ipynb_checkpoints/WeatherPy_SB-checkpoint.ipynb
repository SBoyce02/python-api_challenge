# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# 'acff65e2c0f92b1c69e83a3afd80af31'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['coihaique',
#  'ustka',
#  'hilo',
#  'tatarsk',
#  'mataura',
#  'atuona',
#  'avarua',
#  'bethel',
#  'saldanha',
#  'forbes',
#  'punta arenas',
#  'soyo',
#  'bredasdorp',
#  'jining',
#  'junin',
#  'makurdi',
#  'cap malheureux',
#  'hermanus',
#  'mitsamiouli',
#  'faanui',
#  'isla mujeres',
#  'punta cardon',
#  'busselton',
#  'bengkulu',
#  'timra',
#  'albany',
#  'belushya guba',
#  'tevriz',
#  'rio grande',
#  'ushuaia',
#  'kahului',
#  'mocuba',
#  'thompson',
#  'lebu',
#  'nikolskoye',
#  'tongliao',
#  'ahipara',
#  'zhigansk',
#  'dingle',
#  'benjamin constant',
#  'toftir',
#  'cidreira',
#  'osorio',
#  'attawapiskat',
#  'kaitangata',
#  'barrow',
#  'tiksi',
#  'dafeng',
#  'esperance',
#  'saint anthony',
#  'cape town',
#  'jamestown',
#  'sioux lookout',
#  'tsihombe',
#  'chokurdakh',
#  'berlevag',
#  'saleaula',
#  'liverpool',
#  'georgetown',
#  'patacamaya',
#  'ancud',
#  'qaanaaq',
#  'torbay',
#  'port elizabeth',
#  'hithadhoo',
#  'saskylakh',
#  'palabuhanratu',
#  'grand gaube',
#  'castro',
#  'arraial do cabo',
#  'rikitea',
#  'victoria',
#  'pemangkat',
#  'omsukchan',
#  'pisco',
#  'san juan de uraba',
#  'upernavik',
#  'pangody',
#  'port alfred',
#  'alencon',
#  'grand river south east',
#  'kodiak',
#  'airai',
#  'illoqqortoormiut',
#  'barentsburg',
#  'san juan',
#  'yuancheng',
#  'utete',
#  'santo antonio de padua',
#  'mahebourg',
#  'tasiilaq',
#  'vaini',
#  'lorengau',
#  'husavik',
#  'atar',
#  'aklavik',
#  'dolbeau',
#  'hobart',
#  'ilulissat',
#  'verkhoyansk',
#  'kerman',
#  'renqiu',
#  'dikson',
#  'diamantino',
#  'betanzos',
#  'elizabeth city',
#  'tilichiki',
#  'nakhodka',
#  'butaritari',
#  'bella union',
#  'adrar',
#  'port-gentil',
#  'souillac',
#  'yellowknife',
#  'bluff',
#  'new norfolk',
#  'chuy',
#  'heilbronn',
#  'hailar',
#  'saint-philippe',
#  'lolua',
#  'takoradi',
#  'taolanaro',
#  'tura',
#  'tuktoyaktuk',
#  'portland',
#  'chara',
#  'beringovskiy',
#  'monte patria',
#  'puerto ayora',
#  'mansa',
#  'camacha',
#  'nantucket',
#  'kalmunai',
#  'svetlaya',
#  'kirakira',
#  'kapaa',
#  'malangwa',
#  'carnarvon',
#  'kerrville',
#  'avera',
#  'dakar',
#  'namatanai',
#  'nuuk',
#  'mpika',
#  'dwarka',
#  'constitucion',
#  'meulaboh',
#  'kytmanovo',
#  'niksic',
#  'pokrovsk',
#  'stromness',
#  'leningradskiy',
#  'guerrero negro',
#  'sao joao da barra',
#  'narsaq',
#  'novoagansk',
#  'iqaluit',
#  'crotone',
#  'emerald',
#  'dunedin',
#  'shingu',
#  'myitkyina',
#  'chapais',
#  'san rafael',
#  'nizhneyansk',
#  'coquimbo',
#  'sarkand',
#  'codrington',
#  'temaraia',
#  'barmer',
#  'otavalo',
#  'trelew',
#  'arbazh',
#  'vestmannaeyjar',
#  'acucena',
#  'ribeira grande',
#  'east london',
#  'seminole',
#  'salalah',
#  'dengfeng',
#  'uri',
#  'port hedland',
#  'markova',
#  'tarudant',
#  'martapura',
#  'richards bay',
#  'talnakh',
#  'sretensk',
#  'westpunt',
#  'havelock',
#  'egvekinot',
#  'praya',
#  'denpasar',
#  'pochutla',
#  'severo-yeniseyskiy',
#  'celestun',
#  'altay',
#  'mnogovershinnyy',
#  'mys shmidta',
#  'khatanga',
#  'pokosnoye',
#  'manadhoo',
#  'tocopilla',
#  'feldbach',
#  'daxian',
#  'klaksvik',
#  'opuwo',
#  'tumannyy',
#  'severo-kurilsk',
#  'chagda',
#  'svetlyy',
#  'ukiah',
#  'flinders',
#  'casa nova',
#  'dodge city',
#  'busayra',
#  'cayenne',
#  'los llanos de aridane',
#  'pevek',
#  'tucuman',
#  'san borja',
#  'comodoro rivadavia',
#  'limoeiro do ajuru',
#  'ofaqim',
#  'kuopio',
#  'yulara',
#  'tukums',
#  'grand centre',
#  'provideniya',
#  'hovd',
#  'viligili',
#  'alofi',
#  'atasu',
#  'never',
#  'marienburg',
#  'suoyarvi',
#  'cherskiy',
#  'gazli',
#  'tahta',
#  'malwan',
#  'sentyabrskiy',
#  'turbat',
#  'hasaki',
#  'fort nelson',
#  'ciras',
#  'havre',
#  'ostersund',
#  'qaqortoq',
#  'sorland',
#  'lloydminster',
#  'maragogi',
#  'ponta do sol',
#  'clyde river',
#  'kelso',
#  'ballina',
#  'cabo san lucas',
#  'imbituba',
#  'turayf',
#  'bazarnyye mataki',
#  'lapinigan',
#  'road town',
#  'san lawrenz',
#  'tazovskiy',
#  'vestmanna',
#  'barbar',
#  'morro bay',
#  'korla',
#  'champerico',
#  'mishelevka',
#  'batticaloa',
#  'fuyang',
#  'san policarpo',
#  'mormugao',
#  'fare',
#  'darab',
#  'fairbanks',
#  'udachnyy',
#  'anadyr',
#  'nuevo ideal',
#  'arzgir',
#  'kulhudhuffushi',
#  'erzin',
#  'goderich',
#  'muroto',
#  'bukama',
#  'vila velha',
#  'quatre cocos',
#  'sao jose da coroa grande',
#  'qingdao',
#  'anito',
#  'macapa',
#  'navahrudak',
#  'houma',
#  'saint george',
#  'sinnamary',
#  'tezu',
#  'hinton',
#  'japura',
#  'whitianga',
#  'jiuquan',
#  'romitan',
#  'safranbolu',
#  'praia',
#  'hambantota',
#  'kaele',
#  'yaan',
#  'biak',
#  'la ronge',
#  'asau',
#  'quelimane',
#  'aanekoski',
#  'saint-louis',
#  'morondava',
#  'haines junction',
#  'monrovia',
#  'valdivia',
#  'caiaponia',
#  'ereymentau',
#  'kosh-agach',
#  'okato',
#  'kruisfontein',
#  'hualmay',
#  'viseu',
#  'livingston',
#  'bairiki',
#  'qasigiannguit',
#  'sun city west',
#  'nizwa',
#  'nanortalik',
#  'mirina',
#  'samusu',
#  'petatlan',
#  'vao',
#  'maceio',
#  'banjar',
#  'geraldton',
#  'broken hill',
#  'port augusta',
#  'bagan',
#  'baruun-urt',
#  'panama city',
#  'tungkang',
#  'murray bridge',
#  'port pirie',
#  'amderma',
#  'berekum',
#  'ambulu',
#  'luderitz',
#  'ardakan',
#  'weligama',
#  'cocorit',
#  'pringsewu',
#  'maumere',
#  'taoudenni',
#  'jiwani',
#  'burica',
#  'ormara',
#  'kamsack',
#  'nalut',
#  'yazman',
#  'pachperwa',
#  'tarauaca',
#  'belmonte',
#  'bilibino',
#  'makokou',
#  'roseburg',
#  'darhan',
#  'kupang',
#  'paragould',
#  'dzhusaly',
#  'paragominas',
#  'isangel',
#  'songea',
#  'pacific grove',
#  'antalaha',
#  'collipulli',
#  'farmington',
#  'labuan',
#  'muromtsevo',
#  'santa fe',
#  'maridi',
#  'dubti',
#  'jumla',
#  'ruidoso',
#  'ibotirama',
#  'sechura',
#  'mount gambier',
#  'paradwip',
#  'norman wells',
#  'college',
#  'port moresby',
#  'roald',
#  'mallow',
#  'ouadda',
#  'keith',
#  'sisimiut',
#  'zeya',
#  'natal',
#  'colac',
#  'bolungarvik',
#  'parry sound',
#  'bambous virieux',
#  'jatibonico',
#  'palaikastron',
#  'bac lieu',
#  'santa vitoria do palmar',
#  'longyearbyen',
#  'sumter',
#  'banposh',
#  'mozarlandia',
#  'dudinka',
#  'vaitupu',
#  'san esteban',
#  'margate',
#  'fougamou',
#  'mar del plata',
#  'burnie',
#  'port macquarie',
#  'marawi',
#  'praia da vitoria',
#  'san cristobal',
#  'zhigalovo',
#  'paramonga',
#  'salamiyah',
#  'kailua',
#  'shakiso',
#  'faya',
#  'sherpur',
#  'port keats',
#  'san vicente',
#  'doha',
#  'hit',
#  'trairi',
#  'yuzhno-kurilsk',
#  'artyk',
#  'punta de piedra',
#  'puerto escondido',
#  'tuatapere',
#  'ust-nera',
#  'mildura',
#  'tessalit',
#  'chicama',
#  'cervo',
#  'eureka',
#  'ketchikan',
#  'vardo',
#  'shatrovo',
#  'sitka',
#  'algiers',
#  'melfort',
#  'nouadhibou',
#  'kangaatsiaq',
#  'manassas',
#  'yerbogachen',
#  'pierre',
#  'cacequi',
#  'aberdeen',
#  'puerto baquerizo moreno',
#  'bambanglipuro',
#  'makubetsu',
#  'sambava',
#  'kushiro',
#  'beidao',
#  'suaza',
#  'abu samrah',
#  'novopavlovka',
#  'canete',
#  'sao marcos',
#  'sola',
#  'pestovo',
#  'lagoa',
#  'nang rong',
#  'labuhan',
#  'hohhot',
#  'lompoc',
#  'walvis bay',
#  'bathsheba',
#  'alyangula',
#  'vidim',
#  'dryden',
#  'isernia',
#  'hamilton',
#  'bereznik',
#  'doctor juan leon mallorquin',
#  'kavieng',
#  'kentau',
#  'iskateley',
#  'nyagan',
#  'amuntai',
#  'mayumba',
#  'kozluk',
#  'andilamena',
#  'inuvik',
#  'virginia beach',
#  'lata',
#  'chhapar',
#  'pangnirtung',
#  'acapulco',
#  'da nang',
#  'qujing',
#  'correia pinto',
#  'maniitsoq',
#  'san carlos',
#  'nioro',
#  'solnechnyy',
#  'fortuna',
#  'mehamn',
#  'ust-kamchatsk',
#  'konanur',
#  'khorramshahr',
#  'charters towers',
#  'bacolod',
#  'gimli',
#  'mount isa',
#  'salinas',
#  'kutum',
#  'petropavlovsk-kamchatskiy',
#  'lehututu',
#  'piracuruca',
#  'andreyevo',
#  'mattru',
#  'lavrentiya',
#  'oranjestad',
#  'rabo de peixe',
#  'rocha',
#  'touros',
#  'saurimo',
#  'tutoia',
#  'atambua',
#  'copiapo',
#  'severnoye',
#  'dengzhou',
#  'vila praia de ancora',
#  'zabaykalsk',
#  'potosi',
#  'beloha',
#  'mukhen',
#  'brae',
#  'nerchinskiy zavod',
#  'bilma',
#  'paamiut',
#  'mae chan',
#  'kamenskoye',
#  'balad',
#  'kamaishi',
#  'nguru',
#  'arvika',
#  'veraval',
#  'seoul',
#  'big bend',
#  'rameswaram',
#  'katima mulilo',
#  'auki',
#  'concepcion',
#  'kihei',
#  'kaeo',
#  'katsuura',
#  'koriyama',
#  'kalevala',
#  'sedona',
#  'valparaiso',
#  'el tarra',
#  'dicabisagan',
#  'tautira',
#  'luwuk',
#  'nemuro',
#  'patos',
#  'bulawayo',
#  'huarmey',
#  'labytnangi',
#  'amapa',
#  'vagur',
#  'ternate',
#  'nicoya',
#  'along',
#  'pemba',
#  'methoni',
#  'tank',
#  'vilyuysk',
#  'la primavera',
#  'port hueneme',
#  'sakakah',
#  'andevoranto',
#  'mati',
#  'riyadh',
#  'meyungs',
#  'bur gabo',
#  'nichinan',
#  'westport',
#  'moose factory',
#  'mapiripan',
#  'koscierzyna',
#  'castanos']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
###DO NOT RE RUN THIS CODE IT WILL CREATE A NEW LIST and NEW ANALYSIS!!!!

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"


# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" 
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=acff65e2c0f92b1c69e83a3afd80af31&q='

# %%
#create for loop through API 

#data format in API:
# {"coord":{"lon":-0.1257,"lat":51.5085},"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50n"}],"base":"stations","main":{"temp":38.21,"feels_like":32.56,"temp_min":33.8,"temp_max":41,"pressure":1040,"humidity":75},"visibility":2000,"wind":{"speed":3.44,"deg":230},"clouds":{"all":0},"dt":1614393810,"sys":{"type":1,"id":1414,"country":"GB","sunrise":1614408600,"sunset":1614447406},"timezone":0,"id":2643743,"name":"London","cod":200}


#create list
city_openweather=[]
lat=[]
lon=[]
max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
date=[]




#for loop through city list
for city in cities:
    try:
        
        city_url = query_url + city + "&units=imperial"
        weather = requests.get(city_url).json()
       
        lat.append(weather["coord"]["lat"])
        lon.append(weather["coord"]["lon"])
        max_temp.append(weather["main"]["temp_max"])
        humidity.append(weather["main"]["humidity"])
        cloudiness.append(weather["clouds"]["all"])
        wind_speed.append(weather["wind"]["speed"])
        country.append(weather["sys"]["country"])
        date.append(weather["dt"])
        city_openweather.append(city)
        
        
    except:
        print(f"City not found: {city}")
       
        pass
# Out:
# City not found: belushya guba
# City not found: toftir
# City not found: attawapiskat
# City not found: tsihombe
# City not found: saleaula
# City not found: palabuhanratu
# City not found: grand river south east
# City not found: illoqqortoormiut
# City not found: barentsburg
# City not found: dolbeau
# City not found: lolua
# City not found: taolanaro
# City not found: nizhneyansk
# City not found: temaraia
# City not found: tarudant
# City not found: westpunt
# City not found: mys shmidta
# City not found: daxian
# City not found: tumannyy
# City not found: chagda
# City not found: grand centre
# City not found: viligili
# City not found: malwan
# City not found: sentyabrskiy
# City not found: ciras
# City not found: barbar
# City not found: mirina
# City not found: samusu
# City not found: tungkang
# City not found: amderma
# City not found: burica
# City not found: dzhusaly
# City not found: ruidoso
# City not found: paradwip
# City not found: bolungarvik
# City not found: vaitupu
# City not found: artyk
# City not found: ust-kamchatsk
# City not found: kamenskoye
# City not found: andevoranto
# City not found: meyungs
# City not found: bur gabo

# %%
len(city_openweather)
# Out:
# 552

# %%
len(lat)
# Out:
# 552

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict = {"City": city_openweather, 
             "Latitude": lat, 
             "Longitude": lon,
             "Max Temp": max_temp,         
             "Humidity": humidity,
             "Cloudiness": cloudiness,
             "Wind Speed": wind_speed,
             "Country": country,
             "Date": date}

# %%
city_data= pd.DataFrame(city_dict)
city_data
# Out:
#               City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0        coihaique  -45.5752   -72.0662     55.42        86         100
# 1            ustka   54.5805    16.8619     37.17        90           2
# 2             hilo   19.7297  -155.0900     69.80        83          90
# 3          tatarsk   55.2190    75.9828      8.64        95         100
# 4          mataura  -46.1927   168.8643     70.00        75          53
# ..             ...       ...        ...       ...       ...         ...
# 547       westport   41.1415   -73.3579     39.20        93          90
# 548  moose factory   51.2585   -80.6094     10.40        85          90
# 549      mapiripan    2.8892   -72.1256     78.08        60          47
# 550    koscierzyna   54.1223    17.9812     33.80       100          90
# 551       castanos   26.7833  -101.4167     70.21        63          74
#
#      Wind Speed Country        Date
# 0          4.52      CL  1614569485
# 1          9.06      PL  1614569486
# 2          9.22      US  1614569415
# 3         11.56      RU  1614569487
# 4         11.01      NZ  1614569488
# ..          ...     ...         ...
# 547       10.36      US  1614569670
# 548       14.97      CA  1614569670
# 549        2.75      CO  1614569671
# 550        9.22      PL  1614569671
# 551        4.41      MX  1614569671
#
# [552 rows x 9 columns]

# %%
city_data.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  552.000000  552.000000  552.000000  552.000000  552.000000   552.00000
# mean    19.104493   17.490664   51.691141   73.336957   50.697464     8.27317
# std     33.946759   91.046777   31.430112   20.714169   40.084133     6.08811
# min    -54.800000 -179.166700  -34.600000    1.000000    0.000000     0.16000
# 25%     -9.497525  -65.406950   35.600000   63.000000    1.000000     3.59500
# 50%     23.192500   21.048250   62.710000   78.000000   58.500000     6.91000
# 75%     48.493925  101.356575   75.690000   88.000000   90.000000    11.07750
# max     78.218600  179.316700   98.600000  100.000000  100.000000    34.69000
#
#                Date
# count  5.520000e+02
# mean   1.614570e+09
# std    7.401599e+01
# min    1.614569e+09
# 25%    1.614570e+09
# 50%    1.614570e+09
# 75%    1.614570e+09
# max    1.614570e+09

# %%
city_data.to_csv("../output_data/city data file.csv", index=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#My data  had 23  at 100%  and 529 below 100%


under100_humidity = city_data.loc[city_data["Humidity"] < 100]
len(under100_humidity)
# Out:
# 529

# %%
equal100_humidity = city_data.loc[city_data["Humidity"] == 100]
len(equal100_humidity)
# Out:
# 23

# %%
over100_humidity = city_data.loc[city_data["Humidity"] > 100]
len(over100_humidity)
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data["Latitude"],city_data["Max Temp"], marker="o",color="red", edgecolor = "black")
plt.xlim(-90,90)
plt.ylim(-50,105)
plt.title("City Latitude vs. Max Temperatrue (Fig 1)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("../output_data/Fig1.png")
plt.show()

# %%
#Tempatrues for cities close to the equator are very similar but the further north  you go the lower the temparture is. You don't see this for the southern hemisphere becuase the continient that has the lower temperatures is unpopulated.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data["Latitude"],city_data["Humidity"], marker="o",color="red", edgecolor = "black")
plt.xlim(-90,90)
plt.ylim(0,105)
plt.title("City Latitude vs. Humidity (Fig 2)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.savefig("../output_data/Fig2.png")
plt.show()

# %%
# The majority of the cities on both sides of the equator have a humidity index of 60% or higher.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["Latitude"],city_data["Cloudiness"], marker="o",color="red", edgecolor = "black")
plt.xlim(-90,90)
plt.ylim(0,105)
plt.title("City Latitude vs. Cloudiness (Fig 3)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.savefig("../output_data/Fig3.png")
plt.show()

# %%
#Cloudiness and latitude have no correlation

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["Latitude"],city_data["Wind Speed"], marker="o",color="red", edgecolor = "black")
plt.xlim(-90,90)
plt.ylim(0,40)
plt.title("City Latitude vs. Wind Speed (Fig 4)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.savefig("../output_data/Fig4.png")
plt.show()

# %%
# Latitude and wind speed hav eno correlation, most places no matter where they are at had a wind speed of less than 20 mph.

# %% [markdown]
# ## Linear Regression

# %%
#DEFINE THE NORTHERN HEMISPHERE AND PUT IN DF
#used class activity Portland Crime (Pandas day 2 activty 4)
Northern_Hemisphere = city_data.loc[city_data["Latitude"] >= 0]
Northern_Hemisphere.head(10)
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 1          ustka   54.5805    16.8619     37.17        90           2
# 2           hilo   19.7297  -155.0900     69.80        83          90
# 3        tatarsk   55.2190    75.9828      8.64        95         100
# 7         bethel   41.3712   -73.4140     37.00        95         100
# 13        jining   35.4050   116.5814     35.85        89         100
# 15       makurdi    7.7411     8.5121     73.89        73           5
# 20  isla mujeres   21.2311   -86.7310     80.01        78          40
# 21  punta cardon   11.6581   -70.2150     76.46        78           4
# 24         timra   62.4870    17.3257     39.99        75         100
# 25        albany   42.6001   -73.9662     37.99        75         100
#
#     Wind Speed Country        Date
# 1         9.06      PL  1614569486
# 2         9.22      US  1614569415
# 3        11.56      RU  1614569487
# 7         5.68      US  1614569488
# 13       15.28      CN  1614569491
# 15        5.10      NG  1614569491
# 20       13.80      MX  1614569493
# 21       17.96      VE  1614569493
# 24        5.75      SE  1614569494
# 25        1.99      US  1614569408

# %%
#DEFINE THE SOUTHERN HEMISPHERE AND PUT IN DF
#used class activity Portland Crime (Pandas day 2 activty 4)
Southern_Hemisphere = city_data.loc[city_data["Latitude"] < 0]
Southern_Hemisphere.head(10)
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0      coihaique  -45.5752   -72.0662     55.42        86         100
# 4        mataura  -46.1927   168.8643     70.00        75          53
# 5         atuona   -9.8000  -139.0333     80.35        77          47
# 6         avarua  -21.2078  -159.7750     84.20        79          75
# 8       saldanha  -33.0117    17.9442     57.20        88          92
# 9         forbes  -33.3833   148.0167     96.01        10          41
# 10  punta arenas  -53.1500   -70.9167     41.00        65           0
# 11          soyo   -6.1349    12.3689     79.70        86         100
# 12    bredasdorp  -34.5322    20.0403     68.00        88          36
# 14         junin  -34.5838   -60.9433     72.00        89           0
#
#     Wind Speed Country        Date
# 0         4.52      CL  1614569485
# 4        11.01      NZ  1614569488
# 5        16.42      PF  1614569488
# 6        11.50      CK  1614569488
# 8         4.61      ZA  1614569489
# 9         5.01      AU  1614569489
# 10        4.61      CL  1614569489
# 11       10.80      AO  1614569490
# 12        4.61      ZA  1614569490
# 14        9.80      AR  1614569491

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %%
x_values = Northern_Hemisphere["Latitude"]
y_values = Northern_Hemisphere["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-5,80)
plt.ylim(-50,120)
plt.title("Northern Hemisphere Latitude vs Max Temperature",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Max Temperatutre (F)")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %%
x_values = Southern_Hemisphere["Latitude"]
y_values = Southern_Hemisphere["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-60,10)
plt.ylim(50,105)
plt.title("Southern Hemisphere Latitude vs Max Temperature",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Max Temperatutre (F)")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %%
x_values = Northern_Hemisphere["Latitude"]
y_values = Northern_Hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-5,80)
plt.ylim(-50,120)
plt.title("Northern Hemisphere Latitude vs Max Humidity",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(6,0),fontsize=15,color="black")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %%
x_values = Southern_Hemisphere["Latitude"]
y_values = Southern_Hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-60,10)
plt.ylim(0,105)
plt.title("Southern Hemisphere Latitude vs Humidity",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-20,10),fontsize=15,color="black")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %%
x_values = Northern_Hemisphere["Latitude"]
y_values = Northern_Hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-5,80)
plt.ylim(-50,120)
plt.title("Northern Hemisphere Latitude vs Cloudiness",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,-15), fontsize=15,color="black")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %%
x_values = Southern_Hemisphere["Latitude"]
y_values = Southern_Hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-60,10)
plt.ylim(-5,105)
plt.title("Southern Hemisphere Latitude vs Cloudiness",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,10),fontsize=15,color="black")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %%
x_values = Northern_Hemisphere["Latitude"]
y_values = Northern_Hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-5,80)
plt.ylim(-50,120)
plt.title("Northern Hemisphere Latitude vs Wind Speed",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,-10),fontsize=15,color="black")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232

# %%
x_values = Southern_Hemisphere["Latitude"]
y_values = Southern_Hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.scatter(x_values,y_values, color = "purple", edgecolor = "black")
plt.plot(x_values,regress_values,"r-")
plt.xlim(-60,10)
plt.ylim(-5,40)
plt.title("Southern Hemisphere Latitude vs Wind Soeed",  fontsize=14)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-30,30),fontsize=15,color="black")
plt.show()
